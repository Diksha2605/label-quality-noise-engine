# %%
import os
import sys

SRC_PATH = os.path.abspath("src")
sys.path.insert(0, SRC_PATH)

from phase7_reporting.run_reporting import run_reporting
from phase8_enhancements.widgets import LQNEWidget
import pandas as pd

# Run pipeline to get latest df_train
df_train = run_reporting()  # if you want, we can refactor to return df

# OR load from CSV if already generated
df_train = pd.read_csv("reports/sample_trust_report.csv")

widget = LQNEWidget(df_train)
widget.display()
# Out:
# === Phase 7 + Phase 8.1 + 8.2 + 8.3 ===
# ✅ Relabel queue generated: 300 samples
# ✅ Dataset drift logged
# ✅ Cleaning recommendations generated
# ✅ Phase 8 complete
# ...
